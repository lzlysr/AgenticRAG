# %%
import faiss
index = faiss.read_index("data/indexes/faiss.index")
vec = index.reconstruct(0)
print(vec)
print(vec.shape)
# Out:
# [-0.06087783 -0.00680164 -0.01711525 ... -0.0293386   0.01606327
#   0.05415341]
# (1024,)
